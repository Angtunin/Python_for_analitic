# %% [markdown]
# ## Task 1
# Постройте график<br>
# Назовите график<br>
# Сделайте именование оси x и оси y<br>
# Сделайте выводы
#
# 1.1. Данные из прошлого дз
# 1.2 Изучите стоимости недвижимости

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
plt.hist(df['price'])
plt.xlabel('dollars',)
plt.ylabel('Кол-во')
plt.title('Стоимость домов');

# %% [markdown]
# 1.3 Изучите распределение квадратуры жилой площади

# %%
plt.hist(df['sqft_living'])
plt.xlabel('sqft',)
plt.ylabel('Кол-во')
plt.title('Распределение квадратуры жилой площади');

# %% [markdown]
# 1.4 Изучите распределение года постройки

# %%
plt.hist(df['yr_built'])
plt.xlabel('год')
plt.ylabel('Кол-во')
plt.title('Распределение домов по годам');

# %% [markdown]
# ## Task 2

# %% [markdown]
# 2.1 Изучите распределение домов от наличия вида на набережную

# %%
data = df['waterfront'].value_counts()
data
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
plt.pie(data.values, labels=data.index, autopct='%1.2f%%')
plt.legend(data.index);

# %% [markdown]
# 2.2 Изучите распределение этажей домов

# %%
data = df['floors'].value_counts()
plt.bar(data.index, data.values)
plt.xticks(rotation=0);
plt.grid()

# %% [markdown]
# 2.3 Изучите распределение состояния домов

# %%
data = df['view'].value_counts()

plt.bar(data.index, data.values)
plt.xticks(rotation=0);
plt.grid()

# %% [markdown]
# Зависимость цены дома от количества спален.<br>
# Медианная цена домов увеличивается с увеличением количества спален в доме, данная зависимость сохраняется до 9 спален в доме.<br>
# Наибольший разброс цен в домах с количеством спален = 8

# %%
import seaborn as sns

sns.boxplot(x=df['bedrooms'], y=df['price'], showfliers=False)
plt.xticks(rotation=50);

# %% [markdown]
# Зависимость цены дома от оценки.<br>
# Прослеживается чёткая зависимость: чем выше оценка, тем дороже дом.

# %%
import seaborn as sns
sns.boxplot(x=df['grade'], y=df['price'], showfliers=False)
plt.xticks(rotation=50);

# %% [markdown]
# Зависимость цены дома от количества ванных.<br>
# 1. Чем больше ванных дома тем выше его цена
# 2. Чем больше вынных в доме тем сильнее разброс цен на дома<br>
# (эти зависимости чётко прослеживается до 6 ванных в доме включительно)

# %%
sns.boxplot(x=df['bathrooms'], y=df['price'], showfliers=False)
plt.xticks(rotation=50);

# %% [markdown]
# Зависимость цены от этажности дома.<br>
# самые дорогие дом этажностью в 2,5 этажа

# %%
sns.boxplot(x=df['floors'], y=df['price'], showfliers=False)
plt.xticks(rotation=0);

# %% [markdown]
# Зависимость цены от состояния дома<br>
# Чем выше оценка, тем выше цена.<br>
# Дома с оценкой 1 и 2 очень близки по своей стоимости

# %%
sns.boxplot(x=df['view'], y=df['price'], showfliers=False)
plt.xticks(rotation=50);
